# %%
# !pip install -q -U transformers==4.37.2
# !pip install -q bitsandbytes==0.41.3 accelerate==0.25.0
# !pip install openai-whisper --no-cache-dir
# !pip install -q gradio
# !pip install -q gTTS
# Out:
# Requirement already satisfied: openai-whisper in /home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages (20231117)
# Requirement already satisfied: numba in /home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages (from openai-whisper) (0.59.0)
# Requirement already satisfied: numpy in /home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages (from openai-whisper) (1.24.4)
# Requirement already satisfied: torch in /home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages (from openai-whisper) (2.0.1)
# Requirement already satisfied: tqdm in /home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages (from openai-whisper) (4.66.2)
# Requirement already satisfied: more-itertools in /home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages (from openai-whisper) (10.2.0)
# Requirement already satisfied: tiktoken in /home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages (from openai-whisper) (0.6.0)
# Requirement already satisfied: triton<3,>=2.0.0 in /home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages (from openai-whisper) (2.0.0)
# Requirement already satisfied: cmake in /home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages (from triton<3,>=2.0.0->openai-whisper) (3.28.3)
# Requirement already satisfied: filelock in /home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages (from triton<3,>=2.0.0->openai-whisper) (3.13.1)
# Requirement already satisfied: lit in /home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages (from triton<3,>=2.0.0->openai-whisper) (17.0.6)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in /home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages (from numba->openai-whisper) (0.42.0)
# Requirement already satisfied: regex>=2022.1.18 in /home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages (from tiktoken->openai-whisper) (2023.12.25)
# Requirement already satisfied: requests>=2.26.0 in /home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages (from tiktoken->openai-whisper) (2.31.0)
# Requirement already satisfied: typing-extensions in /home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages (from torch->openai-whisper) (4.9.0)
# Requirement already satisfied: sympy in /home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages (from torch->openai-whisper) (1.12)
# Requirement already satisfied: networkx in /home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages (from torch->openai-whisper) (3.2.1)
# Requirement already satisfied: jinja2 in /home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages (from torch->openai-whisper) (3.1.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages (from torch->openai-whisper) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages (from torch->openai-whisper) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages (from torch->openai-whisper) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages (from torch->openai-whisper) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages (from torch->openai-whisper) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages (from torch->openai-whisper) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages (from torch->openai-whisper) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages (from torch->openai-whisper) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages (from torch->openai-whisper) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages (from torch->openai-whisper) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages (from torch->openai-whisper) (11.7.91)
# Requirement already satisfied: setuptools in /home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch->openai-whisper) (68.2.2)
# Requirement already satisfied: wheel in /home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch->openai-whisper) (0.41.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages (from requests>=2.26.0->tiktoken->openai-whisper) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages (from requests>=2.26.0->tiktoken->openai-whisper) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages (from requests>=2.26.0->tiktoken->openai-whisper) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages (from requests>=2.26.0->tiktoken->openai-whisper) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages (from jinja2->torch->openai-whisper) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages (from sympy->torch->openai-whisper) (1.3.0)

# %%
import torch
from transformers import BitsAndBytesConfig, pipeline
# Out:
# 2024-03-12 00:07:46.281567: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-03-12 00:07:46.324248: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
quantization_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_compute_dtype=torch.float16
)

# %%
model_id = "llava-hf/llava-1.5-7b-hf"

# %%
pipe = pipeline("image-to-text",
                model=model_id,
                model_kwargs={"quantization_config": quantization_config})
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
import gradio as gr
import time
import whisper
import warnings
import os
from gtts import gTTS

# %%
from PIL import Image

# %%
image_path = r'/home/c7361313/vq/Image/zebra.jpg'
image = Image.open((image_path))
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x615>

# %%
# !pip install nltk
# Out:
# Collecting nltk
#   Downloading nltk-3.8.1-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: click in /home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages (from nltk) (8.1.7)
# Collecting joblib (from nltk)
#   Using cached joblib-1.3.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: regex>=2021.8.3 in /home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in /home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages (from nltk) (4.66.2)
# Downloading nltk-3.8.1-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 33.9 MB/s eta 0:00:00 MB/s eta 0:00:01
# Using cached joblib-1.3.2-py3-none-any.whl (302 kB)
# Installing collected packages: joblib, nltk
# Successfully installed joblib-1.3.2 nltk-3.8.1

# %%
import nltk
nltk.download('punkt')
from nltk import sent_tokenize
# Out:
# [nltk_data] Downloading package punkt to /home/c7361313/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
import locale
print(locale.getlocale())  # Before running the pipeline
# Run the pipeline
print(locale.getlocale())  # After running the pipeline
# Out:
# ('en_US', 'UTF-8')
# ('en_US', 'UTF-8')

# %%
max_new_tokens = 200

prompt_instructions = """
Describe the image using as much detail as possible,
is it a painting, a photograph, what colors are predominant,
what is the image about?
"""

prompt = "USER: \n" + prompt_instructions + "\nASSISTANT:"

outputs = pipe(image, prompt=prompt, generate_kwargs={"max_new_tokens": 200})
# outputs
# print(outputs[0]["generated_text"])
for sent in sent_tokenize(outputs[0]["generated_text"]):
    print(sent)
# Out:
# USER:
#
# Describe the image using as much detail as possible,
# is it a painting, a photograph, what colors are predominant,
# what is the image about?
# ASSISTANT: The image features a zebra standing in a lush green field.
# The zebra is the main focus of the scene, and it appears to be looking at the camera.
# The field is filled with grass, providing a natural and serene environment for the zebra.
# The zebra's distinctive black and white stripes are clearly visible, making it an eye-catching subject in the image.

# %%
warnings.filterwarnings("ignore")

# %%
import warnings
from gtts import gTTS
import numpy as np

# %%
torch.cuda.is_available()
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using torch {torch.__version__} ({DEVICE})")
# Out:
# Using torch 2.0.1+cu117 (cuda)

# %%
import whisper
model = whisper.load_model("medium", device=DEVICE)
print(
    f"Model is {'multilingual' if model.is_multilingual else 'English-only'} "
    f"and has {sum(np.prod(p.shape) for p in model.parameters()):,} parameters."
)
# Out:
# 100%|█████████████████████████████████████| 1.42G/1.42G [04:10<00:00, 6.09MiB/s]
# Model is multilingual and has 762,321,920 parameters.

# %%
import re

# %%
input_text = 'What color is the grass in image?'
input_image = '/home/c7361313/vq/Image/zebra.jpg'

# load the image
image = Image.open(input_image)

# prompt_instructions = """
# Describe the image using as much detail as possible, is it a painting, a photograph, what colors are predominant, what is the image about?
# """

# print(input_text)
prompt_instructions = """
Act as an expert in imagery descriptive analysis, using as much detail as possible from the image, respond to the following prompt:
""" + input_text
prompt = "USER: \n" + prompt_instructions + "\nASSISTANT:"

# print(prompt)

outputs = pipe(image, prompt=prompt, generate_kwargs={"max_new_tokens": 200})

match = re.search(r'ASSISTANT:\s*(.*)', outputs[0]["generated_text"])

if match:
    # Extract the text after "ASSISTANT:"
    extracted_text = match.group(1)
    print(extracted_text)
else:
    print("No match found.")

for sent in sent_tokenize(outputs[0]["generated_text"]):
    print(sent)
# Out:
# The grass in the image is green.
# USER:
#
# Act as an expert in imagery descriptive analysis, using as much detail as possible from the image, respond to the following prompt:
# What color is the grass in image?
# ASSISTANT: The grass in the image is green.

# %%
import datetime
import os

# %%
## Logger file
tstamp = datetime.datetime.now()
tstamp = str(tstamp).replace(' ','_')
logfile = f'{tstamp}_log.txt'
def writehistory(text):
    with open(logfile, 'a', encoding='utf-8') as f:
        f.write(text)
        f.write('\n')
    f.close()

# %%
import re
import requests
from PIL import Image

def img2txt(input_text, input_image):

    # load the image
    image = Image.open(input_image)

    writehistory(f"Input text: {input_text} - Type: {type(input_text)} - Dir: {dir(input_text)}")
    if type(input_text) == tuple:
        prompt_instructions = """
        Describe the image using as much detail as possible, is it a painting, a photograph, what colors are predominant, what is the image about?
        """
    else:
        prompt_instructions = """
        Act as an expert in imagery descriptive analysis, using as much detail as possible from the image, respond to the following prompt:
        """ + input_text

    writehistory(f"prompt_instructions: {prompt_instructions}")
    prompt = "USER: \n" + prompt_instructions + "\nASSISTANT:"

    outputs = pipe(image, prompt=prompt, generate_kwargs={"max_new_tokens": 200})

    # Properly extract the response text
    if outputs is not None and len(outputs[0]["generated_text"]) > 0:
        match = re.search(r'ASSISTANT:\s*(.*)', outputs[0]["generated_text"])
        if match:
            # Extract the text after "ASSISTANT:"
            reply = match.group(1)
        else:
            reply = "No response found."
    else:
        reply = "No response generated."

    return reply

# %%
def transcribe(audio):

    # Check if the audio input is None or empty
    if audio is None or audio == '':
        return ('','',None)  # Return empty strings and None audio file

    # language = 'en'

    audio = whisper.load_audio(audio)
    audio = whisper.pad_or_trim(audio)

    mel = whisper.log_mel_spectrogram(audio).to(model.device)

    _, probs = model.detect_language(mel)

    options = whisper.DecodingOptions()
    result = whisper.decode(model, mel, options)
    result_text = result.text

    return result_text

# %%
def text_to_speech(text, file_path):
    language = 'en'

    audioobj = gTTS(text = text,
                    lang = language,
                    slow = False)

    audioobj.save(file_path)

    return file_path

# %%
# !ffmpeg -f lavfi -i anullsrc=r=44100:cl=mono -t 10 -q:a 9 -acodec libmp3lame Temp.mp3
# Out:
# /bin/bash: ffmpeg: command not found
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
import gradio as gr
import base64
import os

# A function to handle audio and image inputs
def process_inputs(audio_path, image_path):
    # Process the audio file (assuming this is handled by a function called 'transcribe')
    speech_to_text_output = transcribe(audio_path)

    # Handle the image input
    if image_path:
        chatgpt_output = img2txt(speech_to_text_output, image_path)
    else:
        chatgpt_output = "No image provided."

    # Assuming 'transcribe' also returns the path to a processed audio file
    processed_audio_path = text_to_speech(chatgpt_output, "Temp3.mp3")  # Replace with actual path if different

    return speech_to_text_output, chatgpt_output, processed_audio_path

# Create the interface
iface = gr.Interface(
    fn=process_inputs,
    inputs=[
        gr.Audio(sources=["microphone"], type="filepath"),
        gr.Image(type="filepath")
    ],
    outputs=[
        gr.Textbox(label="Speech to Text"),
        gr.Textbox(label="ChatGPT Output"),
        gr.Audio("Temp.mp3")
    ],
    title="Learn OpenAI Whisper: Image processing with Whisper and Llava",
    description="Upload an image and interact via voice input and audio response."
)

# Launch the interface
iface.launch(debug=True)
# Out:
# Running on local URL:  http://127.0.0.1:7860
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# ERROR:    Exception in ASGI application
#   + Exception Group Traceback (most recent call last):
#   |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/_utils.py", line 87, in collapse_excgroups
#   |     yield
#   |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/base.py", line 190, in __call__
#   |     async with anyio.create_task_group() as task_group:
#   |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/anyio/_backends/_asyncio.py", line 678, in __aexit__
#   |     raise BaseExceptionGroup(
#   | ExceptionGroup: unhandled errors in a TaskGroup (1 sub-exception)
#   +-+---------------- 1 ----------------
#     | Traceback (most recent call last):
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/uvicorn/protocols/http/h11_impl.py", line 408, in run_asgi
#     |     result = await app(  # type: ignore[func-returns-value]
#     |              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/uvicorn/middleware/proxy_headers.py", line 69, in __call__
#     |     return await self.app(scope, receive, send)
#     |            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/fastapi/applications.py", line 1054, in __call__
#     |     await super().__call__(scope, receive, send)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/applications.py", line 123, in __call__
#     |     await self.middleware_stack(scope, receive, send)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/errors.py", line 186, in __call__
#     |     raise exc
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/errors.py", line 164, in __call__
#     |     await self.app(scope, receive, _send)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/base.py", line 189, in __call__
#     |     with collapse_excgroups():
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/contextlib.py", line 158, in __exit__
#     |     self.gen.throw(typ, value, traceback)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/_utils.py", line 93, in collapse_excgroups
#     |     raise exc
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/base.py", line 191, in __call__
#     |     response = await self.dispatch_func(request, call_next)
#     |                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/gradio/route_utils.py", line 664, in dispatch
#     |     response = await call_next(request)
#     |                ^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/base.py", line 165, in call_next
#     |     raise app_exc
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/base.py", line 151, in coro
#     |     await self.app(scope, receive_or_disconnect, send_no_error)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/exceptions.py", line 62, in __call__
#     |     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/_exception_handler.py", line 64, in wrapped_app
#     |     raise exc
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/_exception_handler.py", line 53, in wrapped_app
#     |     await app(scope, receive, sender)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/routing.py", line 758, in __call__
#     |     await self.middleware_stack(scope, receive, send)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/routing.py", line 778, in app
#     |     await route.handle(scope, receive, send)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/routing.py", line 299, in handle
#     |     await self.app(scope, receive, send)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/routing.py", line 79, in app
#     |     await wrap_app_handling_exceptions(app, request)(scope, receive, send)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/_exception_handler.py", line 64, in wrapped_app
#     |     raise exc
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/_exception_handler.py", line 53, in wrapped_app
#     |     await app(scope, receive, sender)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/routing.py", line 74, in app
#     |     response = await func(request)
#     |                ^^^^^^^^^^^^^^^^^^^
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/fastapi/routing.py", line 278, in app
#     |     raw_response = await run_endpoint_function(
#     |                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/fastapi/routing.py", line 191, in run_endpoint_function
#     |     return await dependant.call(**values)
#     |            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/gradio/routes.py", line 919, in upload_file
#     |     directory.mkdir(exist_ok=True, parents=True)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/pathlib.py", line 1116, in mkdir
#     |     os.mkdir(self, mode)
#     | PermissionError: [Errno 13] Permission denied: '/tmp/gradio/5dd1ef7aba531956a7c4fcf30241471a683ba18e'
#     +------------------------------------
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/uvicorn/protocols/http/h11_impl.py", line 408, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/uvicorn/middleware/proxy_headers.py", line 69, in __call__
#     return await self.app(scope, receive, send)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/fastapi/applications.py", line 1054, in __call__
#     await super().__call__(scope, receive, send)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/applications.py", line 123, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/errors.py", line 186, in __call__
#     raise exc
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/errors.py", line 164, in __call__
#     await self.app(scope, receive, _send)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/base.py", line 189, in __call__
#     with collapse_excgroups():
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/contextlib.py", line 158, in __exit__
#     self.gen.throw(typ, value, traceback)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/_utils.py", line 93, in collapse_excgroups
#     raise exc
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/base.py", line 191, in __call__
#     response = await self.dispatch_func(request, call_next)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/gradio/route_utils.py", line 664, in dispatch
#     response = await call_next(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/base.py", line 165, in call_next
#     raise app_exc
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/base.py", line 151, in coro
#     await self.app(scope, receive_or_disconnect, send_no_error)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/exceptions.py", line 62, in __call__
#     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/_exception_handler.py", line 64, in wrapped_app
#     raise exc
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/_exception_handler.py", line 53, in wrapped_app
#     await app(scope, receive, sender)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/routing.py", line 758, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/routing.py", line 778, in app
#     await route.handle(scope, receive, send)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/routing.py", line 299, in handle
#     await self.app(scope, receive, send)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/routing.py", line 79, in app
#     await wrap_app_handling_exceptions(app, request)(scope, receive, send)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/_exception_handler.py", line 64, in wrapped_app
#     raise exc
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/_exception_handler.py", line 53, in wrapped_app
#     await app(scope, receive, sender)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/routing.py", line 74, in app
#     response = await func(request)
#                ^^^^^^^^^^^^^^^^^^^
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/fastapi/routing.py", line 278, in app
#     raw_response = await run_endpoint_function(
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/fastapi/routing.py", line 191, in run_endpoint_function
#     return await dependant.call(**values)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/gradio/routes.py", line 919, in upload_file
#     directory.mkdir(exist_ok=True, parents=True)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/pathlib.py", line 1116, in mkdir
#     os.mkdir(self, mode)
# PermissionError: [Errno 13] Permission denied: '/tmp/gradio/5dd1ef7aba531956a7c4fcf30241471a683ba18e'
# ERROR:    Exception in ASGI application
#   + Exception Group Traceback (most recent call last):
#   |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/_utils.py", line 87, in collapse_excgroups
#   |     yield
#   |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/base.py", line 190, in __call__
#   |     async with anyio.create_task_group() as task_group:
#   |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/anyio/_backends/_asyncio.py", line 678, in __aexit__
#   |     raise BaseExceptionGroup(
#   | ExceptionGroup: unhandled errors in a TaskGroup (1 sub-exception)
#   +-+---------------- 1 ----------------
#     | Traceback (most recent call last):
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/uvicorn/protocols/http/h11_impl.py", line 408, in run_asgi
#     |     result = await app(  # type: ignore[func-returns-value]
#     |              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/uvicorn/middleware/proxy_headers.py", line 69, in __call__
#     |     return await self.app(scope, receive, send)
#     |            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/fastapi/applications.py", line 1054, in __call__
#     |     await super().__call__(scope, receive, send)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/applications.py", line 123, in __call__
#     |     await self.middleware_stack(scope, receive, send)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/errors.py", line 186, in __call__
#     |     raise exc
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/errors.py", line 164, in __call__
#     |     await self.app(scope, receive, _send)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/base.py", line 189, in __call__
#     |     with collapse_excgroups():
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/contextlib.py", line 158, in __exit__
#     |     self.gen.throw(typ, value, traceback)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/_utils.py", line 93, in collapse_excgroups
#     |     raise exc
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/base.py", line 191, in __call__
#     |     response = await self.dispatch_func(request, call_next)
#     |                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/gradio/route_utils.py", line 664, in dispatch
#     |     response = await call_next(request)
#     |                ^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/base.py", line 165, in call_next
#     |     raise app_exc
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/base.py", line 151, in coro
#     |     await self.app(scope, receive_or_disconnect, send_no_error)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/exceptions.py", line 62, in __call__
#     |     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/_exception_handler.py", line 64, in wrapped_app
#     |     raise exc
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/_exception_handler.py", line 53, in wrapped_app
#     |     await app(scope, receive, sender)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/routing.py", line 758, in __call__
#     |     await self.middleware_stack(scope, receive, send)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/routing.py", line 778, in app
#     |     await route.handle(scope, receive, send)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/routing.py", line 299, in handle
#     |     await self.app(scope, receive, send)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/routing.py", line 79, in app
#     |     await wrap_app_handling_exceptions(app, request)(scope, receive, send)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/_exception_handler.py", line 64, in wrapped_app
#     |     raise exc
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/_exception_handler.py", line 53, in wrapped_app
#     |     await app(scope, receive, sender)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/routing.py", line 74, in app
#     |     response = await func(request)
#     |                ^^^^^^^^^^^^^^^^^^^
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/fastapi/routing.py", line 278, in app
#     |     raw_response = await run_endpoint_function(
#     |                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/fastapi/routing.py", line 191, in run_endpoint_function
#     |     return await dependant.call(**values)
#     |            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/gradio/routes.py", line 919, in upload_file
#     |     directory.mkdir(exist_ok=True, parents=True)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/pathlib.py", line 1116, in mkdir
#     |     os.mkdir(self, mode)
#     | PermissionError: [Errno 13] Permission denied: '/tmp/gradio/8e8524fa245cadee85e8780ecc667338180a85b3'
#     +------------------------------------
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/uvicorn/protocols/http/h11_impl.py", line 408, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/uvicorn/middleware/proxy_headers.py", line 69, in __call__
#     return await self.app(scope, receive, send)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/fastapi/applications.py", line 1054, in __call__
#     await super().__call__(scope, receive, send)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/applications.py", line 123, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/errors.py", line 186, in __call__
#     raise exc
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/errors.py", line 164, in __call__
#     await self.app(scope, receive, _send)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/base.py", line 189, in __call__
#     with collapse_excgroups():
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/contextlib.py", line 158, in __exit__
#     self.gen.throw(typ, value, traceback)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/_utils.py", line 93, in collapse_excgroups
#     raise exc
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/base.py", line 191, in __call__
#     response = await self.dispatch_func(request, call_next)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/gradio/route_utils.py", line 664, in dispatch
#     response = await call_next(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/base.py", line 165, in call_next
#     raise app_exc
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/base.py", line 151, in coro
#     await self.app(scope, receive_or_disconnect, send_no_error)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/exceptions.py", line 62, in __call__
#     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/_exception_handler.py", line 64, in wrapped_app
#     raise exc
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/_exception_handler.py", line 53, in wrapped_app
#     await app(scope, receive, sender)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/routing.py", line 758, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/routing.py", line 778, in app
#     await route.handle(scope, receive, send)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/routing.py", line 299, in handle
#     await self.app(scope, receive, send)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/routing.py", line 79, in app
#     await wrap_app_handling_exceptions(app, request)(scope, receive, send)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/_exception_handler.py", line 64, in wrapped_app
#     raise exc
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/_exception_handler.py", line 53, in wrapped_app
#     await app(scope, receive, sender)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/routing.py", line 74, in app
#     response = await func(request)
#                ^^^^^^^^^^^^^^^^^^^
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/fastapi/routing.py", line 278, in app
#     raw_response = await run_endpoint_function(
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/fastapi/routing.py", line 191, in run_endpoint_function
#     return await dependant.call(**values)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/gradio/routes.py", line 919, in upload_file
#     directory.mkdir(exist_ok=True, parents=True)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/pathlib.py", line 1116, in mkdir
#     os.mkdir(self, mode)
# PermissionError: [Errno 13] Permission denied: '/tmp/gradio/8e8524fa245cadee85e8780ecc667338180a85b3'
# ERROR:    Exception in ASGI application
#   + Exception Group Traceback (most recent call last):
#   |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/_utils.py", line 87, in collapse_excgroups
#   |     yield
#   |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/base.py", line 190, in __call__
#   |     async with anyio.create_task_group() as task_group:
#   |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/anyio/_backends/_asyncio.py", line 678, in __aexit__
#   |     raise BaseExceptionGroup(
#   | ExceptionGroup: unhandled errors in a TaskGroup (1 sub-exception)
#   +-+---------------- 1 ----------------
#     | Traceback (most recent call last):
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/uvicorn/protocols/http/h11_impl.py", line 408, in run_asgi
#     |     result = await app(  # type: ignore[func-returns-value]
#     |              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/uvicorn/middleware/proxy_headers.py", line 69, in __call__
#     |     return await self.app(scope, receive, send)
#     |            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/fastapi/applications.py", line 1054, in __call__
#     |     await super().__call__(scope, receive, send)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/applications.py", line 123, in __call__
#     |     await self.middleware_stack(scope, receive, send)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/errors.py", line 186, in __call__
#     |     raise exc
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/errors.py", line 164, in __call__
#     |     await self.app(scope, receive, _send)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/base.py", line 189, in __call__
#     |     with collapse_excgroups():
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/contextlib.py", line 158, in __exit__
#     |     self.gen.throw(typ, value, traceback)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/_utils.py", line 93, in collapse_excgroups
#     |     raise exc
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/base.py", line 191, in __call__
#     |     response = await self.dispatch_func(request, call_next)
#     |                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/gradio/route_utils.py", line 664, in dispatch
#     |     response = await call_next(request)
#     |                ^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/base.py", line 165, in call_next
#     |     raise app_exc
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/base.py", line 151, in coro
#     |     await self.app(scope, receive_or_disconnect, send_no_error)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/exceptions.py", line 62, in __call__
#     |     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/_exception_handler.py", line 64, in wrapped_app
#     |     raise exc
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/_exception_handler.py", line 53, in wrapped_app
#     |     await app(scope, receive, sender)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/routing.py", line 758, in __call__
#     |     await self.middleware_stack(scope, receive, send)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/routing.py", line 778, in app
#     |     await route.handle(scope, receive, send)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/routing.py", line 299, in handle
#     |     await self.app(scope, receive, send)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/routing.py", line 79, in app
#     |     await wrap_app_handling_exceptions(app, request)(scope, receive, send)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/_exception_handler.py", line 64, in wrapped_app
#     |     raise exc
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/_exception_handler.py", line 53, in wrapped_app
#     |     await app(scope, receive, sender)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/routing.py", line 74, in app
#     |     response = await func(request)
#     |                ^^^^^^^^^^^^^^^^^^^
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/fastapi/routing.py", line 278, in app
#     |     raw_response = await run_endpoint_function(
#     |                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/fastapi/routing.py", line 191, in run_endpoint_function
#     |     return await dependant.call(**values)
#     |            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/gradio/routes.py", line 919, in upload_file
#     |     directory.mkdir(exist_ok=True, parents=True)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/pathlib.py", line 1116, in mkdir
#     |     os.mkdir(self, mode)
#     | PermissionError: [Errno 13] Permission denied: '/tmp/gradio/8e8524fa245cadee85e8780ecc667338180a85b3'
#     +------------------------------------
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/uvicorn/protocols/http/h11_impl.py", line 408, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/uvicorn/middleware/proxy_headers.py", line 69, in __call__
#     return await self.app(scope, receive, send)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/fastapi/applications.py", line 1054, in __call__
#     await super().__call__(scope, receive, send)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/applications.py", line 123, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/errors.py", line 186, in __call__
#     raise exc
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/errors.py", line 164, in __call__
#     await self.app(scope, receive, _send)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/base.py", line 189, in __call__
#     with collapse_excgroups():
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/contextlib.py", line 158, in __exit__
#     self.gen.throw(typ, value, traceback)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/_utils.py", line 93, in collapse_excgroups
#     raise exc
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/base.py", line 191, in __call__
#     response = await self.dispatch_func(request, call_next)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/gradio/route_utils.py", line 664, in dispatch
#     response = await call_next(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/base.py", line 165, in call_next
#     raise app_exc
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/base.py", line 151, in coro
#     await self.app(scope, receive_or_disconnect, send_no_error)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/exceptions.py", line 62, in __call__
#     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/_exception_handler.py", line 64, in wrapped_app
#     raise exc
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/_exception_handler.py", line 53, in wrapped_app
#     await app(scope, receive, sender)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/routing.py", line 758, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/routing.py", line 778, in app
#     await route.handle(scope, receive, send)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/routing.py", line 299, in handle
#     await self.app(scope, receive, send)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/routing.py", line 79, in app
#     await wrap_app_handling_exceptions(app, request)(scope, receive, send)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/_exception_handler.py", line 64, in wrapped_app
#     raise exc
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/_exception_handler.py", line 53, in wrapped_app
#     await app(scope, receive, sender)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/routing.py", line 74, in app
#     response = await func(request)
#                ^^^^^^^^^^^^^^^^^^^
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/fastapi/routing.py", line 278, in app
#     raw_response = await run_endpoint_function(
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/fastapi/routing.py", line 191, in run_endpoint_function
#     return await dependant.call(**values)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/gradio/routes.py", line 919, in upload_file
#     directory.mkdir(exist_ok=True, parents=True)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/pathlib.py", line 1116, in mkdir
#     os.mkdir(self, mode)
# PermissionError: [Errno 13] Permission denied: '/tmp/gradio/8e8524fa245cadee85e8780ecc667338180a85b3'
# ERROR:    Exception in ASGI application
#   + Exception Group Traceback (most recent call last):
#   |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/_utils.py", line 87, in collapse_excgroups
#   |     yield
#   |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/base.py", line 190, in __call__
#   |     async with anyio.create_task_group() as task_group:
#   |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/anyio/_backends/_asyncio.py", line 678, in __aexit__
#   |     raise BaseExceptionGroup(
#   | ExceptionGroup: unhandled errors in a TaskGroup (1 sub-exception)
#   +-+---------------- 1 ----------------
#     | Traceback (most recent call last):
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/uvicorn/protocols/http/h11_impl.py", line 408, in run_asgi
#     |     result = await app(  # type: ignore[func-returns-value]
#     |              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/uvicorn/middleware/proxy_headers.py", line 69, in __call__
#     |     return await self.app(scope, receive, send)
#     |            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/fastapi/applications.py", line 1054, in __call__
#     |     await super().__call__(scope, receive, send)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/applications.py", line 123, in __call__
#     |     await self.middleware_stack(scope, receive, send)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/errors.py", line 186, in __call__
#     |     raise exc
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/errors.py", line 164, in __call__
#     |     await self.app(scope, receive, _send)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/base.py", line 189, in __call__
#     |     with collapse_excgroups():
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/contextlib.py", line 158, in __exit__
#     |     self.gen.throw(typ, value, traceback)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/_utils.py", line 93, in collapse_excgroups
#     |     raise exc
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/base.py", line 191, in __call__
#     |     response = await self.dispatch_func(request, call_next)
#     |                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/gradio/route_utils.py", line 664, in dispatch
#     |     response = await call_next(request)
#     |                ^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/base.py", line 165, in call_next
#     |     raise app_exc
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/base.py", line 151, in coro
#     |     await self.app(scope, receive_or_disconnect, send_no_error)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/exceptions.py", line 62, in __call__
#     |     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/_exception_handler.py", line 64, in wrapped_app
#     |     raise exc
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/_exception_handler.py", line 53, in wrapped_app
#     |     await app(scope, receive, sender)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/routing.py", line 758, in __call__
#     |     await self.middleware_stack(scope, receive, send)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/routing.py", line 778, in app
#     |     await route.handle(scope, receive, send)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/routing.py", line 299, in handle
#     |     await self.app(scope, receive, send)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/routing.py", line 79, in app
#     |     await wrap_app_handling_exceptions(app, request)(scope, receive, send)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/_exception_handler.py", line 64, in wrapped_app
#     |     raise exc
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/_exception_handler.py", line 53, in wrapped_app
#     |     await app(scope, receive, sender)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/routing.py", line 74, in app
#     |     response = await func(request)
#     |                ^^^^^^^^^^^^^^^^^^^
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/fastapi/routing.py", line 278, in app
#     |     raw_response = await run_endpoint_function(
#     |                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/fastapi/routing.py", line 191, in run_endpoint_function
#     |     return await dependant.call(**values)
#     |            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/gradio/routes.py", line 919, in upload_file
#     |     directory.mkdir(exist_ok=True, parents=True)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/pathlib.py", line 1116, in mkdir
#     |     os.mkdir(self, mode)
#     | PermissionError: [Errno 13] Permission denied: '/tmp/gradio/8e8524fa245cadee85e8780ecc667338180a85b3'
#     +------------------------------------
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/uvicorn/protocols/http/h11_impl.py", line 408, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/uvicorn/middleware/proxy_headers.py", line 69, in __call__
#     return await self.app(scope, receive, send)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/fastapi/applications.py", line 1054, in __call__
#     await super().__call__(scope, receive, send)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/applications.py", line 123, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/errors.py", line 186, in __call__
#     raise exc
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/errors.py", line 164, in __call__
#     await self.app(scope, receive, _send)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/base.py", line 189, in __call__
#     with collapse_excgroups():
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/contextlib.py", line 158, in __exit__
#     self.gen.throw(typ, value, traceback)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/_utils.py", line 93, in collapse_excgroups
#     raise exc
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/base.py", line 191, in __call__
#     response = await self.dispatch_func(request, call_next)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/gradio/route_utils.py", line 664, in dispatch
#     response = await call_next(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/base.py", line 165, in call_next
#     raise app_exc
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/base.py", line 151, in coro
#     await self.app(scope, receive_or_disconnect, send_no_error)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/exceptions.py", line 62, in __call__
#     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/_exception_handler.py", line 64, in wrapped_app
#     raise exc
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/_exception_handler.py", line 53, in wrapped_app
#     await app(scope, receive, sender)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/routing.py", line 758, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/routing.py", line 778, in app
#     await route.handle(scope, receive, send)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/routing.py", line 299, in handle
#     await self.app(scope, receive, send)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/routing.py", line 79, in app
#     await wrap_app_handling_exceptions(app, request)(scope, receive, send)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/_exception_handler.py", line 64, in wrapped_app
#     raise exc
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/_exception_handler.py", line 53, in wrapped_app
#     await app(scope, receive, sender)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/routing.py", line 74, in app
#     response = await func(request)
#                ^^^^^^^^^^^^^^^^^^^
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/fastapi/routing.py", line 278, in app
#     raw_response = await run_endpoint_function(
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/fastapi/routing.py", line 191, in run_endpoint_function
#     return await dependant.call(**values)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/gradio/routes.py", line 919, in upload_file
#     directory.mkdir(exist_ok=True, parents=True)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/pathlib.py", line 1116, in mkdir
#     os.mkdir(self, mode)
# PermissionError: [Errno 13] Permission denied: '/tmp/gradio/8e8524fa245cadee85e8780ecc667338180a85b3'
# ERROR:    Exception in ASGI application
#   + Exception Group Traceback (most recent call last):
#   |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/_utils.py", line 87, in collapse_excgroups
#   |     yield
#   |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/base.py", line 190, in __call__
#   |     async with anyio.create_task_group() as task_group:
#   |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/anyio/_backends/_asyncio.py", line 678, in __aexit__
#   |     raise BaseExceptionGroup(
#   | ExceptionGroup: unhandled errors in a TaskGroup (1 sub-exception)
#   +-+---------------- 1 ----------------
#     | Traceback (most recent call last):
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/uvicorn/protocols/http/h11_impl.py", line 408, in run_asgi
#     |     result = await app(  # type: ignore[func-returns-value]
#     |              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/uvicorn/middleware/proxy_headers.py", line 69, in __call__
#     |     return await self.app(scope, receive, send)
#     |            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/fastapi/applications.py", line 1054, in __call__
#     |     await super().__call__(scope, receive, send)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/applications.py", line 123, in __call__
#     |     await self.middleware_stack(scope, receive, send)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/errors.py", line 186, in __call__
#     |     raise exc
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/errors.py", line 164, in __call__
#     |     await self.app(scope, receive, _send)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/base.py", line 189, in __call__
#     |     with collapse_excgroups():
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/contextlib.py", line 158, in __exit__
#     |     self.gen.throw(typ, value, traceback)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/_utils.py", line 93, in collapse_excgroups
#     |     raise exc
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/base.py", line 191, in __call__
#     |     response = await self.dispatch_func(request, call_next)
#     |                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/gradio/route_utils.py", line 664, in dispatch
#     |     response = await call_next(request)
#     |                ^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/base.py", line 165, in call_next
#     |     raise app_exc
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/base.py", line 151, in coro
#     |     await self.app(scope, receive_or_disconnect, send_no_error)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/exceptions.py", line 62, in __call__
#     |     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/_exception_handler.py", line 64, in wrapped_app
#     |     raise exc
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/_exception_handler.py", line 53, in wrapped_app
#     |     await app(scope, receive, sender)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/routing.py", line 758, in __call__
#     |     await self.middleware_stack(scope, receive, send)
# ...
#     +------------------------------------
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/uvicorn/protocols/http/h11_impl.py", line 408, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/uvicorn/middleware/proxy_headers.py", line 69, in __call__
#     return await self.app(scope, receive, send)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/fastapi/applications.py", line 1054, in __call__
#     await super().__call__(scope, receive, send)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/applications.py", line 123, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/errors.py", line 186, in __call__
#     raise exc
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/errors.py", line 164, in __call__
#     await self.app(scope, receive, _send)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/base.py", line 189, in __call__
#     with collapse_excgroups():
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/contextlib.py", line 158, in __exit__
#     self.gen.throw(typ, value, traceback)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/_utils.py", line 93, in collapse_excgroups
#     raise exc
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/base.py", line 191, in __call__
#     response = await self.dispatch_func(request, call_next)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/gradio/route_utils.py", line 664, in dispatch
#     response = await call_next(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/base.py", line 165, in call_next
#     raise app_exc
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/base.py", line 151, in coro
#     await self.app(scope, receive_or_disconnect, send_no_error)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/exceptions.py", line 62, in __call__
#     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/_exception_handler.py", line 64, in wrapped_app
#     raise exc
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/_exception_handler.py", line 53, in wrapped_app
#     await app(scope, receive, sender)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/routing.py", line 758, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/routing.py", line 778, in app
#     await route.handle(scope, receive, send)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/routing.py", line 299, in handle
#     await self.app(scope, receive, send)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/routing.py", line 79, in app
#     await wrap_app_handling_exceptions(app, request)(scope, receive, send)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/_exception_handler.py", line 64, in wrapped_app
#     raise exc
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/_exception_handler.py", line 53, in wrapped_app
#     await app(scope, receive, sender)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/routing.py", line 74, in app
#     response = await func(request)
#                ^^^^^^^^^^^^^^^^^^^
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/fastapi/routing.py", line 278, in app
#     raw_response = await run_endpoint_function(
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/fastapi/routing.py", line 191, in run_endpoint_function
#     return await dependant.call(**values)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/gradio/routes.py", line 919, in upload_file
#     directory.mkdir(exist_ok=True, parents=True)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/pathlib.py", line 1116, in mkdir
#     os.mkdir(self, mode)
# PermissionError: [Errno 13] Permission denied: '/tmp/gradio/8e8524fa245cadee85e8780ecc667338180a85b3'
# ERROR:    Exception in ASGI application
#   + Exception Group Traceback (most recent call last):
#   |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/_utils.py", line 87, in collapse_excgroups
#   |     yield
#   |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/base.py", line 190, in __call__
#   |     async with anyio.create_task_group() as task_group:
#   |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/anyio/_backends/_asyncio.py", line 678, in __aexit__
#   |     raise BaseExceptionGroup(
#   | ExceptionGroup: unhandled errors in a TaskGroup (1 sub-exception)
#   +-+---------------- 1 ----------------
#     | Traceback (most recent call last):
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/uvicorn/protocols/http/h11_impl.py", line 408, in run_asgi
#     |     result = await app(  # type: ignore[func-returns-value]
#     |              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/uvicorn/middleware/proxy_headers.py", line 69, in __call__
#     |     return await self.app(scope, receive, send)
#     |            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/fastapi/applications.py", line 1054, in __call__
#     |     await super().__call__(scope, receive, send)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/applications.py", line 123, in __call__
#     |     await self.middleware_stack(scope, receive, send)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/errors.py", line 186, in __call__
#     |     raise exc
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/errors.py", line 164, in __call__
#     |     await self.app(scope, receive, _send)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/base.py", line 189, in __call__
#     |     with collapse_excgroups():
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/contextlib.py", line 158, in __exit__
#     |     self.gen.throw(typ, value, traceback)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/_utils.py", line 93, in collapse_excgroups
#     |     raise exc
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/base.py", line 191, in __call__
#     |     response = await self.dispatch_func(request, call_next)
#     |                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/gradio/route_utils.py", line 664, in dispatch
#     |     response = await call_next(request)
#     |                ^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/base.py", line 165, in call_next
#     |     raise app_exc
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/base.py", line 151, in coro
#     |     await self.app(scope, receive_or_disconnect, send_no_error)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/exceptions.py", line 62, in __call__
#     |     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/_exception_handler.py", line 64, in wrapped_app
#     |     raise exc
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/_exception_handler.py", line 53, in wrapped_app
#     |     await app(scope, receive, sender)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/routing.py", line 758, in __call__
#     |     await self.middleware_stack(scope, receive, send)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/routing.py", line 778, in app
#     |     await route.handle(scope, receive, send)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/routing.py", line 299, in handle
#     |     await self.app(scope, receive, send)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/routing.py", line 79, in app
#     |     await wrap_app_handling_exceptions(app, request)(scope, receive, send)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/_exception_handler.py", line 64, in wrapped_app
#     |     raise exc
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/_exception_handler.py", line 53, in wrapped_app
#     |     await app(scope, receive, sender)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/routing.py", line 74, in app
#     |     response = await func(request)
#     |                ^^^^^^^^^^^^^^^^^^^
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/fastapi/routing.py", line 278, in app
#     |     raw_response = await run_endpoint_function(
#     |                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/fastapi/routing.py", line 191, in run_endpoint_function
#     |     return await dependant.call(**values)
#     |            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/gradio/routes.py", line 919, in upload_file
#     |     directory.mkdir(exist_ok=True, parents=True)
#     |   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/pathlib.py", line 1116, in mkdir
#     |     os.mkdir(self, mode)
#     | PermissionError: [Errno 13] Permission denied: '/tmp/gradio/8e8524fa245cadee85e8780ecc667338180a85b3'
#     +------------------------------------
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/uvicorn/protocols/http/h11_impl.py", line 408, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/uvicorn/middleware/proxy_headers.py", line 69, in __call__
#     return await self.app(scope, receive, send)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/fastapi/applications.py", line 1054, in __call__
#     await super().__call__(scope, receive, send)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/applications.py", line 123, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/errors.py", line 186, in __call__
#     raise exc
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/errors.py", line 164, in __call__
#     await self.app(scope, receive, _send)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/base.py", line 189, in __call__
#     with collapse_excgroups():
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/contextlib.py", line 158, in __exit__
#     self.gen.throw(typ, value, traceback)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/_utils.py", line 93, in collapse_excgroups
#     raise exc
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/base.py", line 191, in __call__
#     response = await self.dispatch_func(request, call_next)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/gradio/route_utils.py", line 664, in dispatch
#     response = await call_next(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/base.py", line 165, in call_next
#     raise app_exc
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/base.py", line 151, in coro
#     await self.app(scope, receive_or_disconnect, send_no_error)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/middleware/exceptions.py", line 62, in __call__
#     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/_exception_handler.py", line 64, in wrapped_app
#     raise exc
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/_exception_handler.py", line 53, in wrapped_app
#     await app(scope, receive, sender)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/routing.py", line 758, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/routing.py", line 778, in app
#     await route.handle(scope, receive, send)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/routing.py", line 299, in handle
#     await self.app(scope, receive, send)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/routing.py", line 79, in app
#     await wrap_app_handling_exceptions(app, request)(scope, receive, send)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/_exception_handler.py", line 64, in wrapped_app
#     raise exc
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/_exception_handler.py", line 53, in wrapped_app
#     await app(scope, receive, sender)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/starlette/routing.py", line 74, in app
#     response = await func(request)
#                ^^^^^^^^^^^^^^^^^^^
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/fastapi/routing.py", line 278, in app
#     raw_response = await run_endpoint_function(
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/fastapi/routing.py", line 191, in run_endpoint_function
#     return await dependant.call(**values)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/site-packages/gradio/routes.py", line 919, in upload_file
#     directory.mkdir(exist_ok=True, parents=True)
#   File "/home/c7361313/anaconda3/envs/qenv/lib/python3.11/pathlib.py", line 1116, in mkdir
#     os.mkdir(self, mode)
# PermissionError: [Errno 13] Permission denied: '/tmp/gradio/8e8524fa245cadee85e8780ecc667338180a85b3'
# Keyboard interruption in main thread... closing server.

# %%
# !git remote add origin git@github.com:A7mad99/Rag_multimodel.git
# !git branch -M main
# !git push -u origin main
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
